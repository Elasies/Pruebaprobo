# %% [markdown]
# ## Importar librerías

# %%
import cv2
import os
import matplotlib.pyplot as plt
from google.colab import drive

# %% [markdown]
# ## Carga de archivos

# %%
try:
  drive.mount('/content/drive')
except Exception as e:
  print(e)

dataset_name = "Datasetejemplo" # Nombre a asignar para el directorio con los datasets
drive_path = f"/content/drive/My Drive/{dataset_name}" # Nombre de la ubicacion del directorio en la unidad de drive correspondiente
local_path = f"/content/{dataset_name}" # Rulta del directorio local donde se encuentra el dataset
folder_id = "1-46-2HOJYBpH8T462dw3iyCD1a-QKw1h" # id del documento de drive

if os.path.exists(drive_path):
  print(f"Dataset encontrado en la unidad de Google Drive: {drive_path}")
  dataset_path = drive_path
else:
  print(f"Dataset NO encontrado en la unidad de Google Drive: {drive_path}.\
  Procediendo con la descarga...")

  # !pip install -U gdown
  # !gdown -- folder --id {folder_id} -O {drive_path}

  # !mv "/content/{dataset_name}" "drive_path"

  dataset_path = drive_path

print(f"Dataset disponible en: {dataset_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset encontrado en la unidad de Google Drive: /content/drive/My Drive/Datasetejemplo
# Dataset disponible en: /content/drive/My Drive/Datasetejemplo

# %%
# Carga de imagenes con OpenCV
training_dataset_address = os.path.join(dataset_path,'imgs_part_1')
image_files = os.listdir(training_dataset_address)
image_path = os.path.join(training_dataset_address, image_files[2])
image = cv2.imread(image_path)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
print('prueba de ejecucion')
# Out:
# prueba de ejecucion

# %%
print('miku miku beam')
# Out:
# miku miku beam

# %%
print('que juego hizo wilirex')
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
print('otra prueba de mrd')
# Out:
# otra prueba de mrd
